# %% [markdown]
# # Creating a Neural Network from Scratch
# ## Only with numpy (and a little matplotlib)!

# %% [markdown]
# ## TEST AREA

# %%
# Test Area - DO NOT USE
import matplotlib.pyplot as plt
import numpy as np

def sigmoid(x):
    return 1. / (1 + np.exp(-x))

def relu(x):
    return np.maximum(0, x)

x = np.linspace(-2*np.pi, 2*np.pi, 100)
plt.rcParams['figure.figsize'] = [7.50, 3.50]
plt.rcParams['figure.autolayout'] = True

plt.subplot(121)
plt.plot(x, sigmoid(x), color='black')
plt.title("Sigmoid function")

plt.subplot(122)
plt.plot(x, relu(x), color='red')
plt.title("Rectified Linear Unit (ReLU)")

plt.show()

# %% [markdown]
# ## Work Area

# %%
# Imports

import numpy as np
from numpy import random as np_rand
import matplotlib.pyplot as pyt

# %%
# Define a basic class for a node

def sigmoid(x):
    return 1. / (1 + np.exp(-x))

def relu(x):
    return np.maximum(0, x)

class Node():
    
    def __init__(self, input_array, outputs=1):
        self.node_inputs = []
        self.weights = []
        self.bias = np_rand.random_sample()

        for input in input_array:
            self.node_inputs.append(input)
            self.weights.append(np_rand.random_sample())

    def activate(self, threshold=0.6):
        sum = np.dot(self.node_inputs, self.weights)
        sum += self.bias

        return (sum >= threshold)

class Layer():
    def __init__(self, prev_layer):
        pass
